# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
#import statsmodels

# %matplotlib inline

# %%
annual = pd.read_csv('annual_inflation.csv')
semiannual = pd.read_csv('semiannual_inflation.csv')

# %%
semiannual.loc[1::2, 'year'] = semiannual.loc[1::2, 'year'] + 0.5
annual['t'] = annual['year'] - 1913
semiannual['t'] = semiannual['year'] - 1913

# %%
annual
# Out:
#      year  inflation    t
# 0    1913      9.900    0
# 1    1914     10.000    1
# 2    1915     10.100    2
# 3    1916     10.900    3
# 4    1917     12.800    4
# 5    1918     15.100    5
# 6    1919     17.300    6
# 7    1920     20.000    7
# 8    1921     17.900    8
# 9    1922     16.800    9
# 10   1923     17.100   10
# 11   1924     17.100   11
# 12   1925     17.500   12
# 13   1926     17.700   13
# 14   1927     17.400   14
# 15   1928     17.100   15
# 16   1929     17.100   16
# 17   1930     16.700   17
# 18   1931     15.200   18
# 19   1932     13.700   19
# 20   1933     13.000   20
# 21   1934     13.400   21
# 22   1935     13.700   22
# 23   1936     13.900   23
# 24   1937     14.400   24
# 25   1938     14.100   25
# 26   1939     13.900   26
# 27   1940     14.000   27
# 28   1941     14.700   28
# 29   1942     16.300   29
# ..    ...        ...  ...
# 75   1988    118.300   75
# 76   1989    124.000   76
# 77   1990    130.700   77
# ...

# %%
semiannual
# Out:
#        year   inflation      t
# 0    1913.0    9.783333    0.0
# 1    1913.5    9.983333    0.5
# 2    1914.0    9.900000    1.0
# 3    1914.5   10.133333    1.5
# 4    1915.0   10.033333    2.0
# 5    1915.5   10.183333    2.5
# 6    1916.0   10.566667    3.0
# 7    1916.5   11.200000    3.5
# 8    1917.0   12.350000    4.0
# 9    1917.5   13.300000    4.5
# 10   1918.0   14.250000    5.0
# 11   1918.5   15.833333    5.5
# 12   1919.0   16.600000    6.0
# 13   1919.5   18.066667    6.5
# 14   1920.0   20.050000    7.0
# 15   1920.5   20.033333    7.5
# 16   1921.0   18.183333    8.0
# 17   1921.5   17.516667    8.5
# 18   1922.0   16.766667    9.0
# 19   1922.5   16.733333    9.5
# 20   1923.0   16.866667   10.0
# 21   1923.5   17.233333   10.5
# 22   1924.0   17.100000   11.0
# 23   1924.5   17.150000   11.5
# 24   1925.0   17.300000   12.0
# 25   1925.5   17.783333   12.5
# 26   1926.0   17.833333   13.0
# 27   1926.5   17.566667   13.5
# 28   1927.0   17.416667   14.0
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.plot(annual.year, annual.inflation, label='anual')
ax2.plot(semiannual.year, semiannual.inflation, label='semi-annual')
ax1.legend()
ax2.legend()
